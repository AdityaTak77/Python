# %% [markdown]
# ## File operations read and write

# %%
from typing import Concatenate
with open('example.txt', 'r') as file:
    content=file.read()
    print(content)
# Out:
# hi
# good
# ur name

# %%
## read a file line by line

with open('example.txt', 'r') as file:
    for line in file:
        print(line) ## line.strip() remove the newline character
# Out:
# hi
#
# good
#
# ur name

# %%
## writing a file (overwriting)

with open('example.txt', 'w') as file:
    file.write('This is a new line') ## entire content got replaced by this

# %%
## write without overwriting

with open('example.txt','a') as file:
  file.write("append fdgdagadgsadfasdfasdf!\n")

# %%
## writing a list of lines to a flow

lines=['first \n','second \n','third \n']
with open('example.txt','a') as file:
  file.writelines(lines)

# %%
## Binary files

# writing to a bianry file

data = b'\x00\x01\x02'
with open('example.bin', 'wb') as file:
  file.write(data)

# %%
data = b'\x00\x01\x02'
with open('example.bin', 'rb') as file:
  content=file.read()
  print(content)
# Out:
# b'\x00\x01\x02'

# %%
### read the content from a source file and write to destination text file
## copyy in a text file

with open('example.txt','r') as source:
  content = source.read()

with open('destination.txt','w') as destination:
  destination.write(content)

# %%
#Read a text file and count the number of lines, words, and characters.
# Counting lines, words, and characters in a text file
def count_text_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return line_count, word_count, char_count

file_path = 'example.txt'
lines, words, characters = count_text_file(file_path)
print(f'Lines: {lines}, Words: {words}, Characters: {characters}')

# %%
###  ### Writing and then reading a file

with open('example.txt','w+') as file:
    file.write("Hello world\n")
    file.write("This is a new line \n")

    ## Move the file cursor to the beginning
    file.seek(0)

    ## Read the content of the file
    content=file.read()
    print(content)
# Out:
# Hello world
# This is a new line

# %% [markdown]
# ## Working with file paths

# %%
## create a new directory

import os
new="package"
os.mkdir(new)
print(f"directory '{new}' create")
# Out:
# directory 'package' create

# %%
## listing files and directories

items= os.listdir('.')
print(items)
# Out:
# ['.config', 'package', 'sample_data']

# %%
### joining paths

dir="folder"
filename="file.txt"
fullpath=os.path.join(dir,filename)
print(fullpath)
# Out:
# folder/file.txt

# %%
dir="folder"
filename="file.txt"
fullpath=os.path.join(os.getcwd(),dir,filename)
print(fullpath)
# Out:
# /content/folder/file.txt

# %%
path='example.txt'
if os.path.exists(path):
  print(f"the path '{path}' exists ")
else:
  print(f"the path '{path}' does not exist ")
# Out:
# the path 'example.txt' does not exist

# %%
#Checking if a Path is a File or Directory
import os

path = 'example.txt'
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' is neither a file nor a directory.")
# Out:
# The path 'example.txt' is neither a file nor a directory.

# %%
## Getting the absolute path
relative_path='example.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /content/example.txt
