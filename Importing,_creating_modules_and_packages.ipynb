# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaTak77/Python/blob/main/Importing%2C_creating_modules_and_packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hi
