# %% [markdown]
# ## **Import Modules And Packages In Python**

# %% [markdown]
# In Python, modules and packages help organize and reuse code. Here's a comprehensive guide on how to import them.

# %%
import math
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt,pi
print(sqrt(4))
print(pi)
# Out:
# 2.0
# 3.141592653589793

# %%
import numpy as np  ## np is alias
np.array({1,23,4})
# Out:
# array({1, 4, 23}, dtype=object)

# %%
from math import * ## means all packages
sqrt(9)
# Out:
# 3.0

# %%
from package.maths import add
add(2,3)
# Out:
# 5

# %%
from package import maths
maths.add(2,6)
# Out:
# 8

# %% [markdown]
# ## Standard Library

# %%
import array

arr= array.array('i',[1,2,3])
print(arr)
# Out:
# array('i', [1, 2, 3])

# %%
import random
print(random.randint(1,10)) ## provides random no from the range
print(random.random())
print(random.choice(['apple','pic'])) ## for multiple choice
# Out:
# 1
# 0.19317369812863994
# apple

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'package', '.ipynb_checkpoints', 'sample_data']

# %%
os.mkdir('test_dir')

# %%
### high level operations on files and collection of files

import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
### data serlialization
import json
data={'name':'muna','age':44}
json_str= json.dumps(data)
print(json_str)
print(type(json_str))
parseddata=json.loads(json_str)
print(type(parseddata))
# Out:
# {"name": "muna", "age": 44}
# <class 'str'>
# <class 'dict'>

# %%
### csv

import csv

with open('data.csv',mode='w', newline='') as file:
    csv_writer=csv.writer(file)
    csv_writer.writerow(['namee','agee'])
    csv_writer.writerow(['muna',23])
with open('data.csv',mode='r') as file:
    csv_reader=csv.reader(file)
    for row in csv_reader:
        print(row)
# Out:
# ['namee', 'agee']
# ['muna', '23']

# %%
### datetime

from datetime import datetime,timedelta
today=datetime.now()
print(today)
print(today.year)
# Out:
# 2026-04-23 17:55:57.313352
# 2026

# %%
yesterday= today-timedelta(days=1)
print(yesterday)
# Out:
# 2026-04-22 17:55:57.313352

# %%
## time ## to make it sleep
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1776967143.2899806
# 1776967145.2909732

# %%
from ast import pattern
## regular expression

import re

pattern=r'\d+'

t='ther are 4 apple'
match = re.search(pattern,t)
print(match.group)
# Out:
# <built-in method group of re.Match object at 0x7896e1ffd0c0>
